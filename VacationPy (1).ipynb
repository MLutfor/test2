# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install geoviews
# Out:
# Requirement already satisfied: geoviews in c:\users\mklut\anaconda3\lib\site-packages (1.10.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (1.17.0)
# Requirement already satisfied: packaging in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: numpy in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (1.24.3)
# Requirement already satisfied: shapely in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: param in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (1.2.1)
# Requirement already satisfied: pyproj in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\mklut\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\mklut\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\mklut\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.1)
# Requirement already satisfied: pyshp>=2.1 in c:\users\mklut\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\mklut\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\mklut\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\mklut\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in c:\users\mklut\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mklut\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mklut\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mklut\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mklut\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mklut\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mklut\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mklut\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.7)
# Requirement already satisfied: colorama in c:\users\mklut\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\mklut\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\mklut\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\mklut\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\mklut\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mklut\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mklut\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mklut\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mklut\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        hamilton  39.1834  -84.5333    296.95        77          20
# 1        1       mount isa -20.7333  139.5000    294.02        37           3
# 2        2  port elizabeth -33.9180   25.5701    288.76        94           0
# 3        3       adamstown -25.0660 -130.1015    293.99        73         100
# 4        4          tandil -37.3217  -59.1332    290.20        64         100
#
#    Wind Speed Country        Date
# 0        2.06      US  1695938772
# 1        0.00      AU  1695939034
# 2        0.89      ZA  1695938838
# 3        8.00      PN  1695939035
# 4        3.92      AR  1695939035

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Dependencies and Setup
import geoviews as gv
import geoviews.tile_sources as gts

import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Define the Geoapify API endpoint for geocoding
geoapify_endpoint = f"https://api.geoapify.com/v2/geocoding/search?apiKey={geoapify_key}"


# Display sample data
city_data_df.head()

# Create the map plot using hvplot
map_plot = city_data_df.hvplot.scatter(
    x='Lng',           # Longitude
    y='Lat',           # Latitude
    c='Humidity',      # Color by humidity
    cmap='viridis',    # Colormap for color representation
    size='Humidity',   # Size by humidity
    title='City Humidity',  # Plot title
    hover_cols=['City', 'Humidity', 'Country'],  # Data to show on hover
    frame_height=400,  # Height of the plot
    frame_width=600,   # Width of the plot
)

# Display the map
map_plot
# Out:
# C:\Users\mklut\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# :Scatter   [Lng]   (Lat,Humidity,City,Country)

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df.head(6)
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        hamilton  39.1834  -84.5333    296.95        77          20
# 1        1       mount isa -20.7333  139.5000    294.02        37           3
# 2        2  port elizabeth -33.9180   25.5701    288.76        94           0
# 3        3       adamstown -25.0660 -130.1015    293.99        73         100
# 4        4          tandil -37.3217  -59.1332    290.20        64         100
# 5        5        barranca -10.7500  -77.7667    292.40        84          90
#
#    Wind Speed Country        Date
# 0        2.06      US  1695938772
# 1        0.00      AU  1695939034
# 2        0.89      ZA  1695938838
# 3        8.00      PN  1695939035
# 4        3.92      AR  1695939035
# 5        3.56      PE  1695939035

# %%
# Display summary statistics for columns of interest
summary_stats = city_data_df[['Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']].describe()
print(summary_stats)
# Out:
#          Max Temp    Humidity  Cloudiness  Wind Speed
# count  549.000000  549.000000  549.000000  549.000000
# mean   292.457395   70.730419   51.741348    3.620911
# std      9.154774   21.393605   39.420327    2.528771
# min    269.010000   10.000000    0.000000    0.000000
# 25%    285.950000   59.000000   11.000000    1.710000
# 50%    293.890000   77.000000   54.000000    3.090000
# 75%    299.660000   87.000000   95.000000    4.920000
# max    310.740000  100.000000  100.000000   14.980000

# %%
# Relax the criteria to find cities with conditions closer to the example
# Filter cities with Max Temp between 293K and 303K (approximately 20°C to 30°C), Humidity below 85%, Cloudiness equal to or below 10%, and Wind Speed below 5 m/s
filtered_cities_df = city_data_df[(city_data_df['Max Temp'] >= 293) & (city_data_df['Max Temp'] <= 303) &
                                   (city_data_df['Humidity'] < 85) & (city_data_df['Cloudiness'] <= 10) &
                                   (city_data_df['Wind Speed'] < 5)]

# Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

# Display sample data
filtered_cities_df.head
# Out:
# <bound method NDFrame.head of      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 1          1                 mount isa -20.7333  139.5000    294.02        37
# 45        45                   matoury   4.8483  -52.3317    302.13        74
# 57        57                     pasni  25.2631   63.4710    302.11        36
# 68        68                    newman  37.3138 -121.0208    302.62        40
# 75        75                 ambovombe -25.1667   46.0833    294.70        61
# 138      138                  zaragoza  41.6561   -0.8773    298.72        46
# 142      142            chak azam sahu  30.7500   73.0333    298.80        38
# 184      184               ad dawadimi  24.5077   44.3924    299.00        13
# 190      190                     paris  48.8534    2.3488    294.25        77
# 229      229              mersa matruh  31.3525   27.2453    298.80        76
# 241      241                     kanth  29.0667   78.6333    296.35        64
# 267      267                  fukuecho  32.6881  128.8419    298.18        72
# 268      268               as sulayyil  20.4607   45.5779    301.05        18
# 301      301                    mandal  25.4500   74.5667    297.98        46
# 335      335                grand baie -20.0182   57.5802    295.41        75
# 344      344                   bermejo -32.8833  -68.8000    293.10        21
# 349      349                   rahimah  26.7079   50.0619    300.27        56
# 360      360             mammoth lakes  37.6485 -118.9721    295.55        18
# 370      370              saint-tropez  43.2693    6.6398    293.70        57
# 373      373             pacific grove  36.6177 -121.9166    300.51        75
# 374      374                      tezu  27.9167   96.1667    298.46        68
# 377      377  porto barra do ivinheima -22.9667  -53.6667    301.08        46
# 401      401                   tsiombe -25.3000   45.4833    296.10        55
# 413      413                       sur  22.5667   59.5289    302.02        39
# 437      437                  qobustan  40.0824   49.4120    294.26        58
# 454      454            pozo del molle -32.0186  -62.9198    294.87        26
# 455      455                  ad dilam  23.9915   47.1627    301.50        13
# 469      469                 al bawiti  28.3492   28.8659    300.13        52
# 470      470                    olinda  -8.0089  -34.8553    300.00        65
# 486      486                      raya  27.5667   77.7833    298.77        46
# 489      489                siwa oasis  29.2041   25.5195    302.27        39
# 519      519                 dahlonega  34.5326  -83.9849    298.25        75
# 530      530           remire-montjoly   4.9167  -52.2667    302.17        74
# 542      542                carutapera  -1.1950  -46.0200    299.70        71
#
#      Cloudiness  Wind Speed Country        Date
# 1             3        0.00      AU  1695939034
# 45            0        3.60      GF  1695938986
# 57            0        3.96      PK  1695939045
# 68            6        4.47      US  1695938880
# 75            0        4.05      MG  1695939047
# 138           0        0.00      ES  1695939054
# 142           0        3.23      PK  1695939054
# 184           5        4.97      SA  1695939059
# 190           0        4.63      FR  1695938770
# 229           0        3.57      EG  1695939065
# 241           0        0.97      IN  1695938899
# 267           4        3.20      JP  1695939070
# 268           1        1.21      SA  1695939070
# 301           9        1.39      IN  1695939074
# 335           6        1.34      MU  1695939077
# 344           0        4.63      AR  1695939079
# 349           0        1.84      SA  1695939079
# 360           0        1.34      US  1695939081
# 370           5        1.61      FR  1695939082
# 373           0        4.12      US  1695939083
# 374           1        1.73      IN  1695939083
# 377           4        0.75      BR  1695939083
# 401           0        2.97      MG  1695939086
# 413           2        3.03      OM  1695939088
# 437           0        1.53      AZ  1695939091
# 454           0        1.49      AR  1695939093
# 455           1        1.94      SA  1695939093
# 469           0        4.07      EG  1695938839
# 470           0        2.57      BR  1695939095
# 486           0        1.07      IN  1695939097
# 489           0        4.82      EG  1695939097
# 519           0        2.42      US  1695939006
# 530           0        3.60      GF  1695939102
# 542           6        4.14      BR  1695939103  >

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 0        hamilton      US  39.1834  -84.5333        77
# 1       mount isa      AU -20.7333  139.5000        37
# 2  port elizabeth      ZA -33.9180   25.5701        94
# 3       adamstown      PN -25.0660 -130.1015        73
# 4          tandil      AR -37.3217  -59.1332        64

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Import necessary libraries
import pandas as pd
import requests
from api_keys import geoapify_key

# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Define the Geoapify API endpoint for hotel search
hotel_search_endpoint = "https://api.geoapify.com/v2/places"

# Define the parameters for the API request
params = {
    'categories': 'accommodation.hotel',
    'filter': f'circle:{city_data_df["Lng"].iloc[0]},{city_data_df["Lat"].iloc[0]},10000',  # Using the first city's coordinates
    'bias': f'proximity:{city_data_df["Lng"].iloc[0]},{city_data_df["Lat"].iloc[0]}',
    'limit': 20,  # Adjust the limit as needed
    'apiKey': geoapify_key
}

# Create a DataFrame called hotel_df to store hotel information
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()

# Iterate through each row in the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Update the filter and bias parameters with the city's coordinates
    params['filter'] = f'circle:{row["Lng"]},{row["Lat"]},10000'
    params['bias'] = f'proximity:{row["Lng"]},{row["Lat"]}'

    # Make the API request
    response = requests.get(hotel_search_endpoint, params=params)
    data = response.json()

    # Check if 'features' key exists and if the first feature has a 'name' key
    if 'features' in data and data['features'] and 'name' in data['features'][0]['properties']:
        hotel_name = data['features'][0]['properties']['name']
    else:
        hotel_name = "No hotel found"

    # Update the "Hotel Name" column in the DataFrame with the hotel_name
    hotel_df.at[index, 'Hotel Name'] = hotel_name

    # Display the result
    print(f"{row['City']} - nearest hotel: {hotel_name}")
# Out:
# hamilton - nearest hotel: North Vista Manor
# mount isa - nearest hotel: Ibis Styles
# port elizabeth - nearest hotel: Waterford Hotel
# adamstown - nearest hotel: No hotel found
# tandil - nearest hotel: Viñas del Rosario Hotel Boutique
# barranca - nearest hotel: Emperador
# harper - nearest hotel: No hotel found
# invercargill - nearest hotel: The Grand
# port-aux-francais - nearest hotel: Keravel
# almeirim - nearest hotel: Kapejar Hotel
# keflavik - nearest hotel: Núpan Deluxe
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# devils lake - nearest hotel: No hotel found
# saudarkrokur - nearest hotel: Mikligarður
# bredasdorp - nearest hotel: Victoria Hotel
# udachny - nearest hotel: Вилюй
# goz beida - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# bethel - nearest hotel: Hampton Inn Danbury
# serdar - nearest hotel: Chynar Hotel
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# saurimo - nearest hotel: Complexo Hoteleiro de Saurimo
# weno - nearest hotel: High Tide Hotel
# nova sintra - nearest hotel: Residência Ka Dencho
# edinburgh of the seven seas - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# vorkuta - nearest hotel: "Мегаполис"
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# ningbo - nearest hotel: Ningbo Marriott Hotel
# hacienda huancane - nearest hotel: No hotel found
# revda - nearest hotel: Металлург
# mutuali - nearest hotel: No hotel found
# howard springs - nearest hotel: No hotel found
# nemuro - nearest hotel: イーストハーバーホテル
# anadyr - nearest hotel: Гостевой дом
# al jubayl - nearest hotel: Sharq
# margaret river - nearest hotel: Margaret River Hotel
# grytviken - nearest hotel: No hotel found
# yazman - nearest hotel: Yazman Banquet Marriage Hall
# isafjordur - nearest hotel: Hótel Horn
# bilibino - nearest hotel: No hotel found
# jalai nur - nearest hotel: 满洲里福门客栈
# greymouth - nearest hotel: Recreation Hotel
# christchurch - nearest hotel: Ibis Hotel Christchurch
# freetown - nearest hotel: Formal Leona hotel
# matoury - nearest hotel: La Marmotte
# ribeira grande - nearest hotel: Hospedaria JSF
# taltal - nearest hotel: Hostería Taltal
# tralee - nearest hotel: The Ashe Hotel
# saint-philippe - nearest hotel: Le Baril
# waitangi - nearest hotel: Hotel Chathams
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# iqaluit - nearest hotel: Frobisher Inn
# matthew town - nearest hotel: Gaga’s Nest
# westport - nearest hotel: Norwalk Inn and Conference Center
# tiksi - nearest hotel: Арктика
# nagqu - nearest hotel: Naqu Hotel
# pasni - nearest hotel: Juddi Hotel
# constantia - nearest hotel: Hotel Chérica
# kirakira - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# utrik - nearest hotel: No hotel found
# blackmans bay - nearest hotel: Villa Howden
# avarua - nearest hotel: Paradise Inn
# choele choel - nearest hotel: Gran Hotel Choele Choel
# phan rang-thap cham - nearest hotel: Khách Sạn Ninh Thuận
# thompson - nearest hotel: Thompson Inn
# albany - nearest hotel: No hotel found
# newman - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# semey - nearest hotel: Гостинница Милениум
# mili - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# noumea - nearest hotel: Hotel Gondwana
# cockburn town - nearest hotel: The Salt Raker Inn
# ambovombe - nearest hotel: La source
# vila velha - nearest hotel: Hotel Prainha
# port mathurin - nearest hotel: Escale Vacances
# roma - nearest hotel: Wingate by Wyndham Rome
# markovo - nearest hotel: No hotel found
# castanos - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# chonchi - nearest hotel: Hotel Huildín
# castillos - nearest hotel: A mi gente
# dayr mawas - nearest hotel: No hotel found
# badger - nearest hotel: Hotel North Pole
# susuman - nearest hotel: No hotel found
# askino - nearest hotel: No hotel found
# buncrana - nearest hotel: Lake of Shadows Hotel
# papatowai - nearest hotel: No hotel found
# dudinka - nearest hotel: Виктория
# nadi - nearest hotel: President Hotel
# stanley - nearest hotel: Hotel 52
# crane - nearest hotel: No hotel found
# altai - nearest hotel: Altai hotel 40000-100000T
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# lubango - nearest hotel: Novo Hotel
# ust-nera - nearest hotel: гостиница "Солнечная"
# vilyuysk - nearest hotel: Мария
# santa terezinha - nearest hotel: Pousada Santa Terezinha
# vadso - nearest hotel: Scandic Vadsø
# umm kaddadah - nearest hotel: No hotel found
# podgorenskiy - nearest hotel: No hotel found
# arboletes - nearest hotel: Hotel Playa
# kovalam - nearest hotel: Agastya Ayurveda Hotel
# olonkinbyen - nearest hotel: No hotel found
# klyuchi - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# bridgewater - nearest hotel: Comfort Inn
# fort bragg - nearest hotel: Airborne Inn Lodging
# cidreira - nearest hotel: Hotel Castelo
# west island - nearest hotel: Cocos Village Bungalows
# fada n'gourma - nearest hotel: Auberge Diana
# chernyshevskiy - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# st. john's - nearest hotel: Alt Hotel
# jamestown - nearest hotel: DoubleTree Jamestown
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# quelimane - nearest hotel: Mabassa
# atafu village - nearest hotel: No hotel found
# sheridan - nearest hotel: Comfort Inn & Suites
# holualoa - nearest hotel: Kona Hotel
# saint augustine beach - nearest hotel: Castillo Real Resort Hotel
# maumere - nearest hotel: Bogor
# awjilah - nearest hotel: No hotel found
# punta arenas - nearest hotel: Hotel Lacolet
# uturoa - nearest hotel: Hawaiki Nui hotel
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# kharkhorin - nearest hotel: 점심식사 good restaurant.
# carnarvon - nearest hotel: No hotel found
# aykhal - nearest hotel: Уют
# tazacorte - nearest hotel: App Leyma
# yellowknife - nearest hotel: No hotel found
# lagoa - nearest hotel: Casa da Madrinha
# port alfred - nearest hotel: No hotel found
# ciudad lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# huancavelica - nearest hotel: hotel Victoria
# khandyga - nearest hotel: Апельсин
# zaragoza - nearest hotel: Hotel Pilar Plaza
# hami - nearest hotel: Хами
# litchfield - nearest hotel: No hotel found
# dryden - nearest hotel: Holiday Inn Express
# chak azam sahu - nearest hotel: No hotel found
# villa gesell - nearest hotel: Hotel El Faro
# caribou - nearest hotel: Crown Park Inn
# alaghsas - nearest hotel: Hôtel Zagado
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# sisimiut - nearest hotel: Sømandshjemmet
# homer - nearest hotel: Driftwood Inn & Homer Seaside Lodges
# kalmunai - nearest hotel: Saji new food
# ketchikan - nearest hotel: Cape Fox Lodge
# fort saskatchewan - nearest hotel: No hotel found
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# fort st. john - nearest hotel: Fort St. John Motor Inn
# perelyub - nearest hotel: No hotel found
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# san antonio de pale - nearest hotel: No hotel found
# isangel - nearest hotel: Tanna Lodge
# cabo san lucas - nearest hotel: Comfort Rooms
# banda aceh - nearest hotel: Hotel 61
# kidal - nearest hotel: No hotel found
# sept-iles - nearest hotel: Château Arnaud
# talnakh - nearest hotel: Талнах
# williams lake - nearest hotel: Coast Fraser Inn
# sitka - nearest hotel: Aspen Suites Hotel
# georgetown - nearest hotel: Page 63 hostel
# bushehr - nearest hotel: هتل رستوران سیراف
# hermanus - nearest hotel: Aloe guest house
# porto novo - nearest hotel: Hôtel 6500 CFA
# pacasmayo - nearest hotel: Playa Linda
# hithadhoo - nearest hotel: Pebbles Inn
# port hedland - nearest hotel: The Esplanade Hotel
# taro - nearest hotel: Padma Resort Ubud
# votkinsk - nearest hotel: Малахит
# san jose de feliciano - nearest hotel: No hotel found
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# severo-yeniseyskiy - nearest hotel: Актолик
# zaysan - nearest hotel: Рахат қонақүй
# sinabang - nearest hotel: No hotel found
# rongelap - nearest hotel: No hotel found
# nuku'alofa - nearest hotel: City Hotel
# geiro - nearest hotel: No hotel found
# ahlat - nearest hotel: No hotel found
# idaho falls - nearest hotel: Candlewood Suites
# ad dawadimi - nearest hotel: No hotel found
# la sarre - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# smarhon - nearest hotel: Смаргонь
# porto-vecchio - nearest hotel: No hotel found
# iwanai - nearest hotel: ホチルいのう
# paris - nearest hotel: Hôtel Esmerelda
# egilsstadir - nearest hotel: Valaskjálf
# zouerate - nearest hotel: فندق تيرس زمور
# cartagena - nearest hotel: Hotel Bellamar
# tabou - nearest hotel: hôtel le rochet
# touros - nearest hotel: Pousada Atlântico
# cavelossim - nearest hotel: Dona Sylvia Resort
# basco - nearest hotel: Tawsen Hotel
# melouza - nearest hotel: No hotel found
# saynshand - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# kayangel - nearest hotel: No hotel found
# tazovsky - nearest hotel: Тазовчанка
# moose jaw - nearest hotel: Temple Gardens Mineral Spa Resort
# ixtapa - nearest hotel: Ma. Cristina
# aasiaat - nearest hotel: SØMA
# tolanaro - nearest hotel: Hôtel Mahavokey
# santa maria da vitoria - nearest hotel: Hotel Passarela
# namibe - nearest hotel: Hotel Chik Chik Namibe
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# road town - nearest hotel: No hotel found
# hobyo - nearest hotel: No hotel found
# seymour - nearest hotel: Quality Inn & Suites
# codajas - nearest hotel: No hotel found
# plettenberg bay - nearest hotel: Milkwood Manor
# machico - nearest hotel: Residence Inn
# gokceada - nearest hotel: Hasankeyf Apart & Otel
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# walvis bay - nearest hotel: Atlantic
# starominskaya - nearest hotel: Сыродел
# vorgashor - nearest hotel: София
# berezovyy - nearest hotel: No hotel found
# necochea - nearest hotel: Cabañas Río Quequén
# faya-largeau - nearest hotel: No hotel found
# port saint john's - nearest hotel: Outback Inn
# keila - nearest hotel: No hotel found
# selfoss - nearest hotel: Miðgarður
# drayton valley - nearest hotel: Lakeview Inn & Suites
# masterton - nearest hotel: Copthorne Hotel Solway Park
# mersa matruh - nearest hotel: صقور
# mirny - nearest hotel: Зарница
# varallo - nearest hotel: Albergo Italia
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# fada - nearest hotel: No hotel found
# la'ie - nearest hotel: No hotel found
# shizunai-furukawacho - nearest hotel: No hotel found
# satana - nearest hotel: No hotel found
# longyearbyen - nearest hotel: The Vault
# kone - nearest hotel: Pacifik Appartels
# cuamba - nearest hotel: Pensao Cariaco
# debre sina - nearest hotel: Selam Hotel
# kanth - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# ngereklmadel - nearest hotel: No hotel found
# bubaque - nearest hotel: Chez Julio
# jiutai - nearest hotel: No hotel found
# zima - nearest hotel: у Ок'и
# huanan - nearest hotel: No hotel found
# pitimbu - nearest hotel: Pousada Brisa Mar
# coahuayana de hidalgo - nearest hotel: No hotel found
# malango - nearest hotel: Madarana
# hillsborough - nearest hotel: Crowne Plaza San Francisco Airport
# along - nearest hotel: Hotel Toshi Palace
# praia da vitoria - nearest hotel: Salles
# tucurui - nearest hotel: No hotel found
# ayacucho - nearest hotel: Hotel Las Americas
# opuwo - nearest hotel: Ohakane Lodge
# okhotsk - nearest hotel: No hotel found
# belel - nearest hotel: No hotel found
# yerofey pavlovich - nearest hotel: No hotel found
# magadan - nearest hotel: Гостиница «ВМ-Центр»
# mount pearl - nearest hotel: Sandman Signature St. John's
# mejit - nearest hotel: No hotel found
# margate - nearest hotel: The Reading Rooms
# hadibu - nearest hotel: No hotel found
# ivins - nearest hotel: Crescent Moon Inn
# la passe - nearest hotel: L'Estuaire
# fukuecho - nearest hotel: 五島第一ホテル
# as sulayyil - nearest hotel: No hotel found
# kez - nearest hotel: Кама
# katsuura - nearest hotel: 潮騒の宿
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# kodiak - nearest hotel: Shelikof Lodge
# kenai - nearest hotel: Beluga Lookout Hotel
# visby - nearest hotel: Hotell Gute
# alappuzha - nearest hotel: Unnis Hotel
# magomeni - nearest hotel: La Vista Inn
# yelizovo - nearest hotel: Николина Усадьба
# wafangdian - nearest hotel: No hotel found
# el granada - nearest hotel: Beach House
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# queenstown - nearest hotel: Queens Hotel
# zhongshu - nearest hotel: 新天龙酒店
# pemangkat - nearest hotel: Hotel Kelapa Gading
# ginir - nearest hotel: No hotel found
# nicoya - nearest hotel: Hotel marianela
# antalaha - nearest hotel: Hôtel Florida
# ulsteinvik - nearest hotel: Quality Hotel Ulstein
# moranbah - nearest hotel: No hotel found
# salinas - nearest hotel: The Traveler's Hotel
# kiffa - nearest hotel: فندق كيفة
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# saint-pierre - nearest hotel: Tropic Hotel
# garoowe - nearest hotel: Red Sea
# norilsk - nearest hotel: Гостиница Норильск
# pandan - nearest hotel: No hotel found
# gokwe - nearest hotel: No hotel found
# vatra dornei - nearest hotel: Vila Class
# east ballina - nearest hotel: Ballina Beach Resort
# gadzhiyevo - nearest hotel: Оазис
# tura - nearest hotel: No hotel found
# mandal - nearest hotel: No hotel found
# lautoka - nearest hotel: Cathay Hotel
# gamba - nearest hotel: No hotel found
# kodinsk - nearest hotel: Ангара
# puerto armuelles - nearest hotel: Coco del Mar
# lihue - nearest hotel: Kauai Palms
# semirara - nearest hotel: No hotel found
# kalaleh - nearest hotel: No hotel found
# floro - nearest hotel: Comfort Hotel Victoria Florø
# wagar - nearest hotel: No hotel found
# nouadhibou - nearest hotel: Hotel valencia
# yeniseysk - nearest hotel: Отель Енисейский
# enewetak - nearest hotel: No hotel found
# bengkulu - nearest hotel: Dena Hotel
# paradip garh - nearest hotel: Hotel Sea Pearl
# colonia - nearest hotel: Wasserturm Hotel Cologne
# hailar - nearest hotel: 呼伦贝尔融府商务酒店
# iskateley - nearest hotel: Авантаж
# kapa'a - nearest hotel: Pono Kai Resort
# howrah - nearest hotel: Sun India Guest House
# roosevelt - nearest hotel: No hotel found
# niafunke - nearest hotel: No hotel found
# charleston - nearest hotel: Mills House Charleston, Curio Collection by Hilton
# wewak - nearest hotel: Village Inn
# myskhako - nearest hotel: Viva Victoria
# tamanrasset - nearest hotel: فندق الأمان
# gubkinskiy - nearest hotel: Сибирь
# aral - nearest hotel: No hotel found
# nogliki - nearest hotel: Ноглики
# summerlin south - nearest hotel: Element Las Vegas Summerline
# medina - nearest hotel: The Oberoi Madina
# qaqortoq - nearest hotel: Hotel Qaqortoq
# araguaina - nearest hotel: No hotel found
# vernon - nearest hotel: Okanagan Royal Park Inn
# grand baie - nearest hotel: Safari
# papao - nearest hotel: Hiti Moana Villa Lodge
# charters towers - nearest hotel: No hotel found
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# maceio - nearest hotel: Maceió Hostel e Pousada
# stephenville - nearest hotel: No hotel found
# ntchisi - nearest hotel: No hotel found
# sosnovo-ozerskoye - nearest hotel: Озёрная
# hasaki - nearest hotel: 大新旅館
# bermejo - nearest hotel: Muras Aparte Hotel
# bamboo flat - nearest hotel: Hotel Megapode Nest
# huacho - nearest hotel: Hotel Sleep
# kruisfontein - nearest hotel: No hotel found
# greenville - nearest hotel: Quality Inn
# rahimah - nearest hotel: No hotel found
# bolotnoye - nearest hotel: Отдых
# fortaleza - nearest hotel: Hotel Catedral
# sola - nearest hotel: No hotel found
# vung tau - nearest hotel: No hotel found
# sibut - nearest hotel: No hotel found
# george town - nearest hotel: Page 63 hostel
# codrington - nearest hotel: No hotel found
# cuatro cienegas de carranza - nearest hotel: No hotel found
# lumphat - nearest hotel: No hotel found
# sungai penuh - nearest hotel: Hotel Matahari
# mammoth lakes - nearest hotel: Travelodge by Wyndham Mammoth Lakes
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# mana - nearest hotel: Le Samana
# puerto deseado - nearest hotel: Los Olmos
# aplahoue - nearest hotel: Hôtel Immaculé Azovè
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# contamana - nearest hotel: No hotel found
# dampit - nearest hotel: No hotel found
# sekong - nearest hotel: No hotel found
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# saint-tropez - nearest hotel: No hotel found
# vilyuchinsk - nearest hotel: Победа
# arraial do cabo - nearest hotel: No hotel found
# pacific grove - nearest hotel: Pacific Grove Inn
# tezu - nearest hotel: No hotel found
# grand-bassam - nearest hotel: Hôtel 3G
# minas de marcona - nearest hotel: No hotel found
# porto barra do ivinheima - nearest hotel: No hotel found
# krasnyy chikoy - nearest hotel: Гостиница ЗАО "Слюдянка"
# pizarro - nearest hotel: No hotel found
# mutoko - nearest hotel: No hotel found
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# gonabad - nearest hotel: هتل پاسارگاد
# nantucket - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# inhambane - nearest hotel: Hotel de Inhambane
# tangalle - nearest hotel: Coco Tangalla
# blackpool - nearest hotel: Arncliffe Hotel
# kapuskasing - nearest hotel: Travelodge
# parsons - nearest hotel: The Parsonian Hotel
# valparaiso - nearest hotel: Ibis Hotel
# areia branca - nearest hotel: Areia Branca Apart Hotel
# znamenskoye - nearest hotel: No hotel found
# bastrop - nearest hotel: No hotel found
# nizhneangarsk - nearest hotel: No hotel found
# bosaso - nearest hotel: Bosaso hotel
# wotje - nearest hotel: No hotel found
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# puerto baquerizo moreno - nearest hotel: Dory's House
# panama city beach - nearest hotel: Shores of Panama
# south hedland - nearest hotel: Port Haven
# tsiombe - nearest hotel: No hotel found
# siocon - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# n'zeto - nearest hotel: No hotel found
# hastings - nearest hotel: White Rock Hotel
# ariquemes - nearest hotel: Aquarius
# la romana - nearest hotel: Hotel Frano
# kavieng - nearest hotel: Kavieng Hotel
# kavaratti - nearest hotel: No hotel found
# kurumkan - nearest hotel: Туяа
# robore - nearest hotel: Lajas
# sur - nearest hotel: Sur Hotel
# flying fish cove - nearest hotel: Christmas Island Lodge
# kapit - nearest hotel: Haip
# antofagasta - nearest hotel: Hotel Colón
# banff - nearest hotel: Mount Royal Hotel
# lebork - nearest hotel: Hotel Vega
# san clemente del tuyu - nearest hotel: La Argentina
# salekhard - nearest hotel: No hotel found
# sinop - nearest hotel: No hotel found
# nadym - nearest hotel: Янтарная
# kargasok - nearest hotel: Титан
# viedma - nearest hotel: Níjar
# martapura - nearest hotel: Q-Hotel Grand Dafam
# kupang - nearest hotel: HOTEL SALUNGA
# zaozersk - nearest hotel: Северное сияние
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# west haven-sylvan - nearest hotel: Best Western
# arno - nearest hotel: Pensionat Grisslehamns
# taoudenni - nearest hotel: No hotel found
# happy valley-goose bay - nearest hotel: Hotel North Two
# plastun - nearest hotel: Россияночка
# galliano - nearest hotel: Fairfield Inn & Suites by Marriott Cut Off-Galliano
# las terrenas - nearest hotel: Hotel Palococo
# savannah - nearest hotel: Comfort Inn
# qobustan - nearest hotel: No hotel found
# buala - nearest hotel: No hotel found
# vahdat - nearest hotel: Спитамен-44
# kismayo - nearest hotel: Kismayo Hotel
# nago - nearest hotel: グリーンリッチホテル
# vangaindrano - nearest hotel: Fanilo
# zuunmod - nearest hotel: New World Hotel
# itaituba - nearest hotel: TG Hotel
# pirapora - nearest hotel: Hotel Mundial
# cuauhtemoc - nearest hotel: Best Western Cumbres Inn
# san julian - nearest hotel: No hotel found
# sint michiel liber - nearest hotel: Blue Bay Lodges
# puerto ayacucho - nearest hotel: Hotel VENETUR Amazonas
# ancud - nearest hotel: Cabañas
# oranjemund - nearest hotel: Op My Stoep
# quincy - nearest hotel: Howard Johnson
# richards bay - nearest hotel: Bon Hotel Waterfront
# pozo del molle - nearest hotel: La Posada de Ana
# ad dilam - nearest hotel: No hotel found
# chinde - nearest hotel: Kanyum cottage village
# vyritsa - nearest hotel: Гостиница "Оредеж"
# borovskoy - nearest hotel: Маржан
# brookings - nearest hotel: Quality Inn
# port shepstone - nearest hotel: The Spot Backpackers'
# polyarnyy - nearest hotel: No hotel found
# sao miguel do araguaia - nearest hotel: Hotel São Miguel
# raja - nearest hotel: No hotel found
# itupiranga - nearest hotel: No hotel found
# nuuk - nearest hotel: Nordbo
# merano - nearest hotel: Hotel Therme Meran
# amahai - nearest hotel: Onemay Hotel
# tzucacab - nearest hotel: No hotel found
# al bawiti - nearest hotel: Old Oasis Hotel
# olinda - nearest hotel: Fidji Motel
# verkhovyna - nearest hotel: Гуцульський припочівок
# east end - nearest hotel: No hotel found
# alupka - nearest hotel: Сон у моря
# puerto el triunfo - nearest hotel: Motel Jardín
# geraldton - nearest hotel: Ocean Centre Hotel
# mobaye - nearest hotel: No hotel found
# nizhnyaya salda - nearest hotel: No hotel found
# fale old settlement - nearest hotel: No hotel found
# santana - nearest hotel: Hotel Teodoro
# nizhnesortymskiy - nearest hotel: Нижнесортымский
# sampang - nearest hotel: Hotel Trunojoyo (PKPRI)
# kununurra - nearest hotel: Kununurra Country Club Resort
# pohang - nearest hotel: 선 프린스관광호텔
# shahritus - nearest hotel: Marhabo Hotel
# kulhudhuffushi - nearest hotel: No hotel found
# raya - nearest hotel: Vrindavan Garden
# torbat-e jam - nearest hotel: No hotel found
# boende - nearest hotel: Hotel Reference
# siwa oasis - nearest hotel: فندق الكيلانى
# puerto lempira - nearest hotel: Hotel Samaritano
# i-n-salah - nearest hotel: باجودة
# ngurore - nearest hotel: No hotel found
# motueka - nearest hotel: Hotel Motueka
# san pedro - nearest hotel: Hotel Takara
# berdigestyakh - nearest hotel: No hotel found
# callao - nearest hotel: Casa Ronald
# yung shue wan - nearest hotel: 浪濤軒酒店 Concerto Inn
# linxia chengguanzhen - nearest hotel: 如家酒店
# samoylovka - nearest hotel: No hotel found
# kuala belait - nearest hotel: Hotel Sentosa
# longmen - nearest hotel: No hotel found
# tailai - nearest hotel: No hotel found
# leava - nearest hotel: Fia fia
# alofi - nearest hotel: Matavai Resort
# afaahiti - nearest hotel: Omati Lodge
# antsiranana - nearest hotel: Central
# strugi-krasnyye - nearest hotel: МП ЖКХ
# dombarovskiy - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# barki saria - nearest hotel: No hotel found
# cheongju-si - nearest hotel: 그랜드 플라자 호텔
# barguzin - nearest hotel: No hotel found
# posto fiscal rolim de moura - nearest hotel: No hotel found
# ambodifotatra - nearest hotel: Les Palmiers
# kyzyl-mazhalyk - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# fedorovskiy - nearest hotel: Маяк
# dahlonega - nearest hotel: Days Inn
# alakurtti - nearest hotel: No hotel found
# aswan - nearest hotel: Yaseen hotel
# lagos - nearest hotel: No hotel found
# atherton - nearest hotel: Britannia Hotel
# springbok - nearest hotel: Elkoweru Guesthouse
# strabane - nearest hotel: Fir Trees Hotel
# aweil - nearest hotel: Aweil Grand Hotel
# laguna - nearest hotel: Holiday Inn Express & Suites
# hood river - nearest hotel: Hood River Hotel
# nurota - nearest hotel: Nurota
# remire-montjoly - nearest hotel: Complexe Belova
# kailua-kona - nearest hotel: Kona Seaside Hotel
# prainha - nearest hotel: No hotel found
# bardai - nearest hotel: No hotel found
# baiti - nearest hotel: No hotel found
# shimanovsk - nearest hotel: Таёжная
# ambon - nearest hotel: Hotel Hero
# new norfolk - nearest hotel: Woodbridge on the Derwent
# ridgecrest - nearest hotel: Best Western China Lake Inn
# broken hill - nearest hotel: Ibis Styles
# aoulef - nearest hotel: دار الضياف
# bairnsdale - nearest hotel: Main hotel
# carutapera - nearest hotel: No hotel found
# plottier - nearest hotel: Hotel Costa del Limay
# bandarbeyla - nearest hotel: No hotel found
# lashio - nearest hotel: Golden Kaniri Hotel
# prince rupert - nearest hotel: Crest Hotel
# el nido - nearest hotel: Dragonfly
# masjed soleyman - nearest hotel: هتل جهانگردی

# %%
# Display the updated DataFrame
hotel_df.head(5)
# Out:
#              City Country      Lat       Lng  Humidity  \
# 0        hamilton      US  39.1834  -84.5333        77
# 1       mount isa      AU -20.7333  139.5000        37
# 2  port elizabeth      ZA -33.9180   25.5701        94
# 3       adamstown      PN -25.0660 -130.1015        73
# 4          tandil      AR -37.3217  -59.1332        64
#
#                          Hotel Name
# 0                 North Vista Manor
# 1                       Ibis Styles
# 2                   Waterford Hotel
# 3                    No hotel found
# 4  Viñas del Rosario Hotel Boutique

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# %%
# Save hotel_df to a CSV file
hotel_df.to_csv('hotel_data.csv', index=False)
hotel_df = pd.read_csv("hotel_data.csv")

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import numpy as np  # Import NumPy library

# Create the map plot using hvplot, including the 'Hotel Name' column
map_plot = hotel_df.hvplot.scatter(
    x='Lng',           # Longitude
    y='Lat',           # Latitude
    c='Humidity',      # Color by humidity
    cmap='viridis',    # Colormap for color representation
    size='Humidity',   # Size by humidity
    title='City Humidity with Hotel Names',  # Plot title
    hover_cols=['City', 'Humidity', 'Hotel Name'],  # Data to show on hover (including city name, humidity, and hotel name)
    frame_height=400,  # Height of the plot
    frame_width=600,   # Width of the plot
)

# Display the map
map_plot
# Out:
# :Scatter   [Lng]   (Lat,Humidity,City,Hotel Name)
